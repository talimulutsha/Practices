# %% [markdown]
# # Cross Validation
# - Cross validation is a tecnique to evaluate a model by splitting the data into train and test sets
# - Cross validation can be used in machine learning
# - The training set is used to train the model, while the test set is used to evaluate the model's performance
#
# Cross validation is a statistical technique used to evaluate the performance of a model on unseen data. It is used to check how well a model generalizes to new, unseen data.
#
#
#
# Cross-validation is a crucial technique in machine learning for assessing the performance of a predictive model. It's particularly important in situations where the available dataset is limited. Here's how it works:
#
# 1. **Data Splitting**: The dataset is divided into two subsets: the training set and the validation (or test) set. Typically, the data is divided into k subsets or folds.
#
# 2. **Training and Validation**: The model is trained on k-1 folds of the data and validated on the remaining fold. This process is repeated k times, each time with a different fold held out for validation.
#
# 3. **Performance Evaluation**: After k iterations, the performance metric (such as accuracy, precision, recall, etc.) is calculated on each validation fold. The average performance across all folds is then computed to evaluate the model's overall performance.
#
# Common types of cross-validation include:
# - **k-Fold Cross-Validation**: The dataset is divided into k equal-sized folds. Each fold is used as the validation set once while the k-1 remaining folds form the training set.
# - **Leave-One-Out Cross-Validation (LOOCV)**: Each observation in the dataset is used once as the validation data, and the rest of the data is used for training. This is repeated for each observation.
# - **Stratified Cross-Validation**: Ensures that each fold of the cross-validation dataset is representative of the whole dataset. This is particularly useful when dealing with imbalanced datasets.
#
# Cross-validation helps in assessing how well a model generalizes to unseen data, providing a more reliable estimate of its performance compared to simply using a single train-test split. It helps in detecting overfitting or underfitting and aids in hyperparameter tuning.

# %%
# importing librairies
from sklearn.datasets import load_iris
from sklearn.model_selection import cross_val_score
from sklearn.naive_bayes import GaussianNB

# load the data
iris= load_iris()

# define the Gaussian naive bayes model
nb = GaussianNB()


# perform k-fold cross validation with k=5
scores = cross_val_score(nb, iris.data, iris.target, cv=5, scoring = 'accuracy')

# print the accuracy
print("scores for each fold: ", scores)
print("mean accuracy: ", scores.mean())
print("standard deviation: ", scores.std())
# Out:
# scores for each fold:  [0.93333333 0.96666667 0.93333333 0.93333333 1.        ]
# mean accuracy:  0.9533333333333334
# standard deviation:  0.02666666666666666

# %% [markdown]
# ###  plotting cross validation

# %% [markdown]
# how to check cross validation result

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier

# load the iris dataset
iris = load_iris()
X = iris.data
y = iris.target

# train and evaluate the decision tree classifier
clf = DecisionTreeClassifier()
scores = cross_val_score(clf, X, y, cv=8)



# plot the result
plt.figure(figsize=(8, 6))
plt.plot(range(1, 9), scores, color= 'blue', linestyle= 'dashed', marker= 'o', markerfacecolor= 'red', markersize= 10)
plt.title('Kfold cross validation result')
plt.xlabel('Kfold number')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1.0])
plt.show()
